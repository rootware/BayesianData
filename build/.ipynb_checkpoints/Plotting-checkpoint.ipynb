# %%
import matplotlib.pyplot as plt;
import numpy as np;
import matplotlib

# %%
BlochData = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/nMom9Good/Blochpop.dat");

# %%
plt.plot(BlochData)
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
ax=plt.gca();
ax.plot(BlochData[:,0], label="n=0");
ax.plot(BlochData[:,1], label="n=1");

ax.legend();
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
ax=plt.gca();

ax.plot(BlochData[:,3], label="n=3");
ax.plot(BlochData[:,4], label="n=4");

ax.legend();
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
ax=plt.gca();

ax.plot(BlochData[:,5], label="n=5");
ax.plot(BlochData[:,6], label="n=6");

ax.legend();
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
ax=plt.gca();

ax.plot(BlochData[:,7], label="n=7");
ax.plot(BlochData[:,8], label="n=8");
ax.legend();
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
MomentumData = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/nMom9Good/Momentum.dat");

# %%
ax=plt.gca();
ax.plot(MomentumData[:,2], label="$p= -4\hbar k_L$")
ax.plot(MomentumData[:,6], label="$p= +4\hbar k_L$")
ax.legend()

# %%
ax=plt.gca();
ax.plot(MomentumData[:,0], label="$p= -8\hbar k_L$")
ax.plot(MomentumData[:,8], label="$p= +8\hbar k_L$")
ax.legend()

# %%
ax=plt.gca();
ax.plot(MomentumData[:,1], label="$p= -6\hbar k_L$")
ax.plot(MomentumData[:,7], label="$p= +6\hbar k_L$")
ax.legend()

# %%
ax=plt.gca();
ax.plot(MomentumData[:,3], label="$p= -2\hbar k_L$")
ax.plot(MomentumData[:,5], label="$p= +2\hbar k_L$")
ax.legend()

# %%
ax=plt.gca();
ax.plot(MomentumData[:,4], label="$p= 0\hbar k_L$");
ax.legend()

# %%
plt.imshow(MomentumData, extent=[-8,9,33,0])

# %%
CFIData=np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/nMom9Good/CFI.dat");

# %%
plt.plot(CFIData)
plt.ylabel("CFI")
# Out:
# Text(0, 0.5, 'CFI')

# %%
matplotlib.rcParams['figure.figsize'] = (20, 10)
plt.subplot(1,2,1);

def theoreticalCFI(action):
    time = action*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi
ax=plt.gca();

line1=ax.plot([CFIData.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
plt.subplot(1,2,2);
plt.imshow(MomentumData)
plt.ylabel("No. of actions")
plt.title("Momentum populations")
plt.xlabel("Momentum, index 5 is $p=0\hbar$k")
plt.savefig("Off Diagonal CFI Plots.png")

# %%
np.sum(BlochData[5,:])
# Out:
# 2.26995072

# %%
BlochData.shape
# Out:
# (31, 9)

# %%
np.sum(MomentumData[10,:])
# Out:
# 0.98782811

# %%
plt.plot( [ np.sum(MomentumData[i,:]) for i in range(0,30) ] )

# %% [markdown]
# # Improve nStep = 100

# %%
MomentumData2 = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/Momentum.dat");

# %%
matplotlib.rcParams['figure.figsize'] = (20, 10)
plt.subplot(1,2,1);
plt.imshow(MomentumData2)
plt.ylabel("No. of actions")
plt.title("Momentum populations")
plt.xlabel("Momentum, index 5 is $p=0\hbar$k")
plt.savefig("Off Diagonal CFI Plots.png")

plt.subplot(1,2,2);
plt.imshow(MomentumData)
plt.ylabel("No. of actions")
plt.title("Momentum populations")
plt.xlabel("Momentum, index 5 is $p=0\hbar$k")
plt.savefig("Off Diagonal CFI Plots.png")

# %%
plt.plot( [ np.sum(MomentumData[i,:]) for i in range(0,30) ] )
plt.plot( [ np.sum(MomentumData2[i,:]) for i in range(0,30) ] )

# %%
CFIData=np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/nMom9Good/CFI.dat");
CFIData2=np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/CFI.dat");

# %%
def theoreticalCFI(action):
    time = action*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();line1=ax.plot([CFIData.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
line1=ax.plot([CFIData2.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI2/(MZ QFI)")
line2=ax.plot([CFIData2.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI2/(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')

# %%
def theoreticalCFI(action):
    time = 30*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();line1=ax.plot([CFIData.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
line1=ax.plot([CFIData2.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI with better RK4/(MZ QFI)")
line2=ax.plot([CFIData2.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI with better RK4 /(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')

# %% [markdown]
# # Change Feature: Add time derivative

# %%
MomentumData_T = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/Momentum.dat")
CFIData_T = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/CFI.dat")

# %%
plt.imshow(MomentumData_T)
plt.ylabel("No. of actions")
plt.title("Momentum populations")
plt.xlabel("Momentum, index 5 is $p=0\hbar$k")
plt.savefig("Off Diagonal CFI Plots.png")

# %%
plt.plot( [ 1-np.sum(MomentumData_T[i,:]) for i in range(0,30) ] )

# %%
1-MomentumData_T[0,:]
# Out:
# array([0.99999998, 0.99998879, 0.99740112, 0.865441  , 0.274339  ,
#        0.865441  , 0.99740112, 0.99998879, 0.99999998])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def surface_plot (matrix, **kwargs):
    # acquire the cartesian coordinate matrices from the matrix
    # x is cols, y is rows
    (x, y) = (x, y) = np.meshgrid(np.arange(matrix.shape[1]), np.arange(matrix.shape[0]))
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(x, y, matrix, **kwargs)
    return (fig, ax, surf)

m = MomentumData_T

(fig, ax, surf) = surface_plot(m, cmap=plt.cm.coolwarm)

fig.colorbar(surf)

ax.set_xlabel('Momentum)')
ax.set_ylabel('Time)')
ax.set_zlabel('P(p|a=0.0)')
ax.view_init(elev=55, azim=-50)

plt.title("Splitting for MaxSteps = 64")
# Out:
# Text(0.5, 0.92, 'Splitting for MaxSteps = 64')

# %%
def theoreticalCFI(action):
    time = action*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();line1=ax.plot([CFIData.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData_T.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
line2=ax.plot([CFIData_T.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI /(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')

# %%
plt.imshow(MomentumData_T[18:22,:])

# %%
ax=plt.gca();

ax.plot(MomentumData_T[:,1], label="$p= -6\hbar k_L$")
ax.plot(MomentumData_T[:,7], label="$p= +6\hbar k_L$")
ax.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_T[:,2], label="$p= -4\hbar k_L$", marker='x')
ax.plot(MomentumData_T[:,6], label="$p= +4\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_T[:,3], label="$p= -2\hbar k_L$", marker='x')
ax.plot(MomentumData_T[:,5], label="$p= +2\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_T[:,4], label="$p= \pm 0\hbar k_L$", marker='x')
plt.legend()

# %% [markdown]
# # Taupo Run with 200 episodes, epsilonDecay 0.6

# %%
MomentumData_taupo = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/Momentum.dat")
CFIData_taupo = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/CFI.dat")

# %%
def theoreticalCFI(action):
    time = action*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();
line1=ax.plot([CFIData_taupo.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData_taupo.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')

# %%
ax=plt.gca()
ax.plot(MomentumData_taupo[:,1], label="$p= -6\hbar k_L$", marker='x')
ax.plot(MomentumData_taupo[:,7], label="$p= +6\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_taupo[:,0], label="$p= -8\hbar k_L$", marker='x')
ax.plot(MomentumData_taupo[:,8], label="$p= +8\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_taupo[:,2], label="$p= -4\hbar k_L$", marker='x')
ax.plot(MomentumData_taupo[:,6], label="$p= +4\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_taupo[:,3], label="$p= -2\hbar k_L$", marker='x')
ax.plot(MomentumData_taupo[:,5], label="$p= +2\hbar k_L$", marker='x')
plt.legend()

# %% [markdown]
# # Reduce Replay Buffer Size

# %%
MomentumData_R = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/ReduceReplayBufferSize/Momentum.dat")
CFIData_R = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/ReduceReplayBufferSize/CFI.dat")

# %%
plt.imshow(MomentumData_R)

# %%
def theoreticalCFI(action):
    time = 30*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();
line1=ax.plot([CFIData_R.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData_R.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')

# %%
def theoreticalCFI(action):
    time = action*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();
line1=ax.plot([CFIData_R.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI/(MZ QFI)")
line2=ax.plot([CFIData_R.transpose()[-1][i]/theoreticalCFI(i) for i in range(1,31)], label="QFI/(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')

# %%
ax=plt.gca()
ax.plot(MomentumData_R[:,2], label="$p= -4\hbar k_L$", marker='x')
ax.plot(MomentumData_R[:,6], label="$p= +4\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_R[:,0], label="$p= -8\hbar k_L$", marker='x')
ax.plot(MomentumData_R[:,8], label="$p= +8\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_R[:,1], label="$p= -6\hbar k_L$", marker='x')
ax.plot(MomentumData_R[:,7], label="$p= +6\hbar k_L$", marker='x')
plt.legend()

# %%
ax=plt.gca()
ax.plot(MomentumData_R[:,1]+MomentumData_R[:,7], label="$p= |\pm 6|\hbar k_L$", marker='x')
ax.plot(MomentumData_R[:,2]+MomentumData_R[:,6], label="$p= |\pm 4|\hbar k_L$", marker='x')
ax.plot(MomentumData_R[:,0]+MomentumData_R[:,8], label="$p= |\pm 8|\hbar k_L$", marker='x')
ax.plot(MomentumData_R[:,3]+MomentumData_R[:,5], label="$p= |\pm 2|\hbar k_L$", marker='x')
plt.legend()

# %%
BlochData= np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/ReduceReplayBufferSize/Blochpop.dat")
ax=plt.gca();

ax.plot(BlochData[:,3], label="n=3");
ax.plot(BlochData[:,4], label="n=4");

ax.legend();
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
plt.plot( [ 1-np.sum(BlochData[i,:]) for i in range(0,30) ] )

# %% [markdown]
# # Fix Bug in BlochPop
# Use reducereplaybuffer action file to regenerate files

# %%
BlochDatabefore= np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/ReduceReplayBufferSize/Blochpop.dat")
BlochDatanow = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/Blochpop.dat")

# %%
plt.plot( [ 1-np.sum(BlochDatabefore[i,:]) for i in range(0,30) ], label="pre bug fix" )
plt.plot([ 1-np.sum(BlochDatanow[i,:]) for i in range(0,30) ] , label="postbug fix")
plt.legend()

# %%
plt.plot([ 1-np.sum(BlochDatanow[i,:]) for i in range(0,30) ] , label="postbug fix")
plt.legend()

# %%
ax=plt.gca();

ax.plot(BlochDatanow[:,3], label="n=3");
ax.plot(BlochDatanow[:,4], label="n=4");

ax.legend();
plt.title("Bloch populations")
# Out:
# Text(0.5, 1.0, 'Bloch populations')

# %%
MomentumData_N = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/Momentum.dat")
CFIData_N = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/CFI.dat")

# %%
ax=plt.gca()
ax.plot(MomentumData_N[:,1], label="$p= -6\hbar k_L$", marker='x')
ax.plot(MomentumData_N[:,7], label="$p= +6\hbar k_L$", marker='x')
plt.legend()

# %%
MomentumData_P = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/ReduceReplayBufferSizeWithFixedBlochPop/Momentum.dat")
CFIData_P = np.loadtxt("/home/labuser/End2End_CFIM_FeatureExp/build/ReduceReplayBufferSizeWithFixedBlochPop/CFI.dat")

# %%
ax=plt.gca()
ax.plot(MomentumData_P[:,1], label="$p= -6\hbar k_L$", marker='x')
ax.plot(MomentumData_P[:,7], label="$p= +6\hbar k_L$", marker='x')
plt.legend()

# %%
def theoreticalCFI(action):
    time = action*np.pi/11.5
    cfi = (2*4*time**2)**2/4
    return cfi

ax=plt.gca();
line1=ax.plot([CFIData_N.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI with Toggle POS/(MZ QFI)")
line2=ax.plot([CFIData_P.transpose()[0][i]/theoreticalCFI(i) for i in range(1,31)], label="CFI with Toggle NEG/(MZ QFI)")
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.ylabel("QFI/CFI")
plt.title("CFI and QFI, normalized with MZ QFI, Reward = "+ "$I_{aa}$")
# Out:
# Text(0.5, 1.0, 'CFI and QFI, normalized with MZ QFI, Reward = $I_{aa}$')
